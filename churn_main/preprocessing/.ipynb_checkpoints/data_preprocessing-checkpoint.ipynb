# %% [markdown]
# ### Importing the required packages

# %%
# Packages / libraries
import os #provides functions for interacting with the operating system
import numpy as np 
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns
import warnings

# %matplotlib inline

# To install sklearn type "pip install numpy scipy scikit-learn" to the anaconda terminal

# To change scientific numbers to float
np.set_printoptions(formatter={'float_kind':'{:f}'.format})

# Increases the size of sns plots
sns.set(rc={'figure.figsize':(10,8)})


# remove warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ### Load the raw data from csv file

# %%
# Loading the data
raw_data = pd.read_csv(r"C:\Users\user\Desktop\AI projects\Churn-prediction\BankChurners.csv")

# print the shape
print(raw_data.shape)

raw_data = raw_data.drop(['Naive_Bayes_Classifier_Attrition_Flag_Card_Category_Contacts_Count_12_mon_Dependent_count_Education_Level_Months_Inactive_12_mon_1', 'Naive_Bayes_Classifier_Attrition_Flag_Card_Category_Contacts_Count_12_mon_Dependent_count_Education_Level_Months_Inactive_12_mon_2'], axis=1)

raw_data
# Out:
# (10127, 23)
#        CLIENTNUM     Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 0      768805383  Existing Customer            45      M                3
# 1      818770008  Existing Customer            49      F                5
# 2      713982108  Existing Customer            51      M                3
# 3      769911858  Existing Customer            40      F                4
# 4      709106358  Existing Customer            40      M                3
# ...          ...                ...           ...    ...              ...
# 10122  772366833  Existing Customer            50      M                2
# 10123  710638233  Attrited Customer            41      M                2
# 10124  716506083  Attrited Customer            44      F                1
# 10125  717406983  Attrited Customer            30      M                2
# 10126  714337233  Attrited Customer            43      F                2
#
# ...

# %%
raw_data.dtypes
# Out:
# CLIENTNUM                     int64
# Attrition_Flag               object
# Customer_Age                  int64
# Gender                       object
# Dependent_count               int64
# Education_Level              object
# Marital_Status               object
# Income_Category              object
# Card_Category                object
# Months_on_book                int64
# Total_Relationship_Count      int64
# Months_Inactive_12_mon        int64
# Contacts_Count_12_mon         int64
# Credit_Limit                float64
# Total_Revolving_Bal           int64
# Avg_Open_To_Buy             float64
# Total_Amt_Chng_Q4_Q1        float64
# Total_Trans_Amt               int64
# Total_Trans_Ct                int64
# Total_Ct_Chng_Q4_Q1         float64
# Avg_Utilization_Ratio       float64
# dtype: object

# %%
raw_data.loc[10125]
# Out:
# CLIENTNUM                           717406983
# Attrition_Flag              Attrited Customer
# Customer_Age                               30
# Gender                                      M
# Dependent_count                             2
# Education_Level                      Graduate
# Marital_Status                        Unknown
# Income_Category                   $40K - $60K
# Card_Category                            Blue
# Months_on_book                             36
# Total_Relationship_Count                    4
# Months_Inactive_12_mon                      3
# Contacts_Count_12_mon                       3
# Credit_Limit                           5281.0
# Total_Revolving_Bal                         0
# Avg_Open_To_Buy                        5281.0
# Total_Amt_Chng_Q4_Q1                    0.535
# Total_Trans_Amt                          8395
# Total_Trans_Ct                             62
# Total_Ct_Chng_Q4_Q1                     0.722
# ...

# %% [markdown]
# ### Data Preprocessing
# #### Exploratory Data Analysis & Data Cleaning

# %%
churn_rate = len(raw_data.loc[raw_data['Attrition_Flag']== 'Attrited Customer'])*100/len(raw_data)
churn_rate
# Out:
# 16.065962279055988

# %%
# # create new age category based on grouping the age column
# raw_data['Customer_Age_category'] = raw_data['Customer_Age']
# raw_data['Customer_Age_category'][(raw_data['Customer_Age'] >= 26) & (raw_data['Customer_Age'] <=33)] = "26-33"
# raw_data['Customer_Age_category'][(raw_data['Customer_Age'] >= 34) & (raw_data['Customer_Age'] <=43)] = "34-43"
# raw_data['Customer_Age_category'][(raw_data['Customer_Age'] >= 44) & (raw_data['Customer_Age'] <=53)] = "44-53"
# raw_data['Customer_Age_category'][(raw_data['Customer_Age'] >= 54) & (raw_data['Customer_Age'] <=63)] = "54-63"
# raw_data['Customer_Age_category'][(raw_data['Customer_Age'] >= 64) & (raw_data['Customer_Age'] <=73)] = "64-73"

# raw_data['Customer_Age_category']

# %%
# Investigate all the elements whithin each Feature 

for column in raw_data:
    unique_vals = np.unique(raw_data[column])
    nr_values = len(unique_vals)
    if nr_values < 10:
        print('The number of values for feature {} :{} -- {}'.format(column, nr_values,unique_vals))
    else:
        print('The number of values for feature {} :{}'.format(column, nr_values))
# Out:
# The number of values for feature CLIENTNUM :10127
# The number of values for feature Attrition_Flag :2 -- ['Attrited Customer' 'Existing Customer']
# The number of values for feature Customer_Age :45
# The number of values for feature Gender :2 -- ['F' 'M']
# The number of values for feature Dependent_count :6 -- [0 1 2 3 4 5]
# The number of values for feature Education_Level :7 -- ['College' 'Doctorate' 'Graduate' 'High School' 'Post-Graduate'
#  'Uneducated' 'Unknown']
# The number of values for feature Marital_Status :4 -- ['Divorced' 'Married' 'Single' 'Unknown']
# The number of values for feature Income_Category :6 -- ['$120K +' '$40K - $60K' '$60K - $80K' '$80K - $120K' 'Less than $40K'
#  'Unknown']
# The number of values for feature Card_Category :4 -- ['Blue' 'Gold' 'Platinum' 'Silver']
# The number of values for feature Months_on_book :44
# The number of values for feature Total_Relationship_Count :6 -- [1 2 3 4 5 6]
# ...

# %%
raw_data.dtypes
# Out:
# CLIENTNUM                     int64
# Attrition_Flag               object
# Customer_Age                  int64
# Gender                       object
# Dependent_count               int64
# Education_Level              object
# Marital_Status               object
# Income_Category              object
# Card_Category                object
# Months_on_book                int64
# Total_Relationship_Count      int64
# Months_Inactive_12_mon        int64
# Contacts_Count_12_mon         int64
# Credit_Limit                float64
# Total_Revolving_Bal           int64
# Avg_Open_To_Buy             float64
# Total_Amt_Chng_Q4_Q1        float64
# Total_Trans_Amt               int64
# Total_Trans_Ct                int64
# Total_Ct_Chng_Q4_Q1         float64
# Avg_Utilization_Ratio       float64
# dtype: object

# %%
# Checking for null values

raw_data.isnull().sum()
# Out:
# CLIENTNUM                   0
# Attrition_Flag              0
# Customer_Age                0
# Gender                      0
# Dependent_count             0
# Education_Level             0
# Marital_Status              0
# Income_Category             0
# Card_Category               0
# Months_on_book              0
# Total_Relationship_Count    0
# Months_Inactive_12_mon      0
# Contacts_Count_12_mon       0
# Credit_Limit                0
# Total_Revolving_Bal         0
# Avg_Open_To_Buy             0
# Total_Amt_Chng_Q4_Q1        0
# Total_Trans_Amt             0
# Total_Trans_Ct              0
# Total_Ct_Chng_Q4_Q1         0
# Avg_Utilization_Ratio       0
# dtype: int64

# %%
# Getting the columns we need

raw_data.columns
# Out:
# Index(['CLIENTNUM', 'Attrition_Flag', 'Customer_Age', 'Gender',
#        'Dependent_count', 'Education_Level', 'Marital_Status',
#        'Income_Category', 'Card_Category', 'Months_on_book',
#        'Total_Relationship_Count', 'Months_Inactive_12_mon',
#        'Contacts_Count_12_mon', 'Credit_Limit', 'Total_Revolving_Bal',
#        'Avg_Open_To_Buy', 'Total_Amt_Chng_Q4_Q1', 'Total_Trans_Amt',
#        'Total_Trans_Ct', 'Total_Ct_Chng_Q4_Q1', 'Avg_Utilization_Ratio'],
#       dtype='object')

# %%
# #selecting the columns that I want to check the correlation between them
n_variables = [ 'Attrition_Flag', 'Customer_Age', 'Gender',
       'Dependent_count', 'Education_Level', 'Marital_Status','Income_Category', 'Card_Category', 'Months_on_book',
    'Total_Relationship_Count', 'Months_Inactive_12_mon','Contacts_Count_12_mon', 'Credit_Limit', 'Total_Revolving_Bal','Avg_Open_To_Buy', 
               'Total_Amt_Chng_Q4_Q1', 'Total_Trans_Amt','Total_Trans_Ct', 'Total_Ct_Chng_Q4_Q1', 'Avg_Utilization_Ratio']

# creating the correlation dataset using Pearson method (linear relation)
pc = raw_data.corr(method ='pearson')

# %%
pc
# Out:
#                           CLIENTNUM  Customer_Age  Dependent_count  \
# CLIENTNUM                  1.000000      0.007613         0.006772
# Customer_Age               0.007613      1.000000        -0.122254
# Dependent_count            0.006772     -0.122254         1.000000
# Months_on_book             0.134588      0.788912        -0.103062
# Total_Relationship_Count   0.006907     -0.010931        -0.039076
# Months_Inactive_12_mon     0.005729      0.054361        -0.010768
# Contacts_Count_12_mon      0.005694     -0.018452        -0.040505
# Credit_Limit               0.005708      0.002476         0.068065
# Total_Revolving_Bal        0.000825      0.014780        -0.002688
# Avg_Open_To_Buy            0.005633      0.001151         0.068291
# Total_Amt_Chng_Q4_Q1       0.017369     -0.062042        -0.035439
# Total_Trans_Amt           -0.019692     -0.046446         0.025046
# Total_Trans_Ct            -0.002961     -0.067097         0.049912
# ...

# %%
# Looping through all the features by our y variable - see if there is relationship

features = ['Attrition_Flag',  'Gender','Customer_Age',
       'Dependent_count', 'Education_Level', 'Marital_Status',
       'Income_Category', 'Card_Category', 'Total_Relationship_Count',
        'Months_Inactive_12_mon', 'Contacts_Count_12_mon']

for f in features:
    sns.countplot(x = f, data = raw_data, palette = 'Set3')
    plt.xticks(rotation=45)
    plt.show()

# %%
raw_data.columns
# Out:
# Index(['CLIENTNUM', 'Attrition_Flag', 'Customer_Age', 'Gender',
#        'Dependent_count', 'Education_Level', 'Marital_Status',
#        'Income_Category', 'Card_Category', 'Months_on_book',
#        'Total_Relationship_Count', 'Months_Inactive_12_mon',
#        'Contacts_Count_12_mon', 'Credit_Limit', 'Total_Revolving_Bal',
#        'Avg_Open_To_Buy', 'Total_Amt_Chng_Q4_Q1', 'Total_Trans_Amt',
#        'Total_Trans_Ct', 'Total_Ct_Chng_Q4_Q1', 'Avg_Utilization_Ratio'],
#       dtype='object')

# %% [markdown]
# ### Feature Engineering - Numeric Representation

# %%
# # Making categorical variables into numeric representation

# print(raw_data.shape)

# # keeping the columns we need
# raw_data2 = raw_data[features]

# print(raw_data.shape)

# # Making categorical variables into numeric representation
# new_raw_data = pd.get_dummies(raw_data2)

# # print the shape

# new_raw_data['Credit_Limit']= raw_data['Credit_Limit']
# new_raw_data['Total_Revolving_Bal']= raw_data['Total_Revolving_Bal']
# new_raw_data['Total_Trans_Ct']= raw_data['Total_Trans_Ct']
# new_raw_data['Avg_Utilization_Ratio']= raw_data['Avg_Utilization_Ratio']

# %%
# choosing the feutures (just original numerical data)
new_raw_data = raw_data.drop(['CLIENTNUM', 'Customer_Age', 'Gender',
       'Dependent_count', 'Education_Level', 'Marital_Status',
       'Income_Category', 'Card_Category'], axis = 1)

# %%
print(new_raw_data.shape)
# Out:
# (10127, 13)

# %%
# Remover column header and index
new_raw_data.to_csv(r"C:\Users\user\Desktop\AI projects\Churn-prediction/bank_model_data.csv",index=False)
